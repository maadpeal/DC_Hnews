# %% [markdown]
# ## Reading hacker news:
# * In this project we're going to develop the neccesary script to analysis the dataset:https://www.kaggle.com/hacker-news/hacker-news-posts
# * The main objective consist in take the data and manipulated until we can see patterns.

# %%
from csv import reader
opened_file = open('hacker_news.csv')
read_file = reader(opened_file)
hn = list(read_file)

# %%
#hn[:5] # display the first five rows

# %%
headers = hn[0] # Saving headers

# %%
hn = hn[1:] #Saving without headers

# %%
#headers # display headers

# %%
#hn[:5] #display the first five rows without header

# %%
ask_posts = []
show_posts = []
other_posts = []

# %%
#In this step we're going to separated the publications
for row in hn:
    title = row[1].lower()
    if title.startswith('ask hn'):
        ask_posts.append(row)
    elif title.startswith('show hn'):
        show_posts.append(row)
    else:
        other_posts.append(row)

# %%
#len(other_posts) #the number of posts is 34.386
#len(ask_posts) #the number of posts is 3.488
#len(show_posts) #the number of posts is 2.324

# %%
#ask_posts num_comments 4
# here we add the comments by each publication
def totalComments(lista, indice):
    total_comments = 0
    for row in lista:
        num_comments = int(row[indice])
        total_comments += num_comments
    return total_comments

# %%
total = totalComments(ask_posts, 4)
avg_ask_comments = total / len(ask_posts)
print(avg_ask_comments)
# Out:
# 14.038417431192661

# %%
total_show = totalComments(show_posts, 4)
avg_show_comments = total_show / len(show_posts)
print(avg_show_comments)
# Out:
# 10.31669535283993

# %%
import datetime as dt

# %%
result_list = []
for row in ask_posts:
    created_at = row[6]
    num_comments = int(row[4])
    result_list.append([created_at, num_comments])
counts_by_hour = {}
comments_by_hour = {}
for row in result_list:
    date, time = row[0].split()
    #print(time) #here is the hour
    #print(date) #8/28/2016
    date = dt.datetime.strptime(date, '%m/%d/%Y')
    if time not in counts_by_hour:
        counts_by_hour[time] = 1
        comments_by_hour[time] = row[1]
    else:
        counts_by_hour[time] += 1
        comments_by_hour[time] += row[1]

# %%
#counts_by_hour # show the hour numbers
#comments_by_hour #show the comments by hour

# %%
avg_by_hour = []
for row in counts_by_hour:
    avg_by_hour.append([row, comments_by_hour[row] / counts_by_hour[row]])

# %%
avg_by_hour[:2]
# Out:
# [['9:55', 3.25], ['13:43', 39.5]]

# %%
swap_avg_by_hour = []
for element in avg_by_hour:
    swap_avg_by_hour.append([element[1], element[0]])
sorted_swap = swap_avg_by_hour.sort(reverse = True)
#print(swap_avg_by_hour)
sorted_swap = swap_avg_by_hour
print(sorted_swap[:3])
# Out:
# [[434.5, '2:07'], [350.0, '16:43'], [266.0, '11:52']]

# %%
for element in sorted_swap[:5]:
    print(element)
# Out:
# [434.5, '2:07']
# [350.0, '16:43']
# [266.0, '11:52']
# [258.0, '20:57']
# [239.5, '20:18']

# %%
for lista in sorted_swap:
    date = dt.datetime.strptime(lista[1], '%H:%M')
    date = dt.datetime.strftime(date, '%H:%M')
    string = "{} {:.2f} average comments per post".format(date, lista[0])
    print(string)
# Out:
# 02:07 434.50 average comments per post
# 16:43 350.00 average comments per post
# 11:52 266.00 average comments per post
# 20:57 258.00 average comments per post
# 20:18 239.50 average comments per post
# 13:04 231.00 average comments per post
# 15:00 223.67 average comments per post
# 15:01 196.56 average comments per post
# 18:35 193.50 average comments per post
# 17:02 182.00 average comments per post
# 21:03 178.33 average comments per post
# 15:52 144.00 average comments per post
# 15:40 128.00 average comments per post
# 19:37 120.50 average comments per post
# 16:13 112.00 average comments per post
# 15:07 111.00 average comments per post
# 10:25 109.00 average comments per post
# 02:22 101.00 average comments per post
# 21:23 95.00 average comments per post
# 20:30 95.00 average comments per post
# 13:40 95.00 average comments per post
# 10:04 90.00 average comments per post
# 15:27 85.50 average comments per post
# 14:35 85.00 average comments per post
# 06:06 73.00 average comments per post
# 12:38 73.00 average comments per post
# 10:01 71.00 average comments per post
# 21:00 66.50 average comments per post
# 14:43 66.00 average comments per post
# 08:52 65.50 average comments per post
# 23:54 65.00 average comments per post
# 12:12 64.50 average comments per post
# 11:23 64.50 average comments per post
# 04:15 62.00 average comments per post
# 14:53 60.33 average comments per post
# 09:30 60.00 average comments per post
# 18:44 59.25 average comments per post
# 20:39 58.00 average comments per post
# 17:18 55.00 average comments per post
# 16:14 55.00 average comments per post
# 06:38 54.00 average comments per post
# 07:51 53.00 average comments per post
# 00:04 53.00 average comments per post
# 16:57 52.00 average comments per post
# 14:50 51.00 average comments per post
# 21:31 50.67 average comments per post
# 21:04 50.00 average comments per post
# 10:08 49.00 average comments per post
# 17:31 47.00 average comments per post
# 19:19 46.00 average comments per post
# 08:33 45.00 average comments per post
# 05:58 44.33 average comments per post
# 03:05 44.00 average comments per post
# 01:30 43.00 average comments per post
# 12:28 43.00 average comments per post
# 00:05 43.00 average comments per post
# 02:24 41.00 average comments per post
# 19:28 40.40 average comments per post
# 13:20 40.40 average comments per post
# 20:45 40.00 average comments per post
# 13:43 39.50 average comments per post
# 04:35 37.00 average comments per post
# 14:58 37.00 average comments per post
# 15:42 36.50 average comments per post
# 17:50 36.00 average comments per post
# 01:31 35.00 average comments per post
# 13:31 34.00 average comments per post
# 15:23 33.00 average comments per post
# 10:33 33.00 average comments per post
# 03:58 32.00 average comments per post
# 18:03 32.00 average comments per post
# 00:33 32.00 average comments per post
# 00:16 32.00 average comments per post
# 05:26 31.00 average comments per post
# 17:34 31.00 average comments per post
# 15:49 31.00 average comments per post
# 13:57 31.00 average comments per post
# 10:59 31.00 average comments per post
# 08:42 29.67 average comments per post
# 08:56 29.00 average comments per post
# 19:55 28.67 average comments per post
# 17:05 28.50 average comments per post
# 12:44 28.33 average comments per post
# 01:22 28.00 average comments per post
# 15:35 27.75 average comments per post
# 14:16 27.50 average comments per post
# 23:15 27.00 average comments per post
# 18:14 27.00 average comments per post
# 01:39 26.67 average comments per post
# 20:58 26.00 average comments per post
# 13:23 26.00 average comments per post
# 06:53 25.50 average comments per post
# 13:52 25.25 average comments per post
# 02:06 25.00 average comments per post
# 23:47 25.00 average comments per post
# 14:11 25.00 average comments per post
# 14:45 24.40 average comments per post
# 18:09 24.33 average comments per post
# 14:34 24.00 average comments per post
# 10:02 24.00 average comments per post
# 01:24 23.50 average comments per post
# 09:33 23.00 average comments per post
# 01:57 23.00 average comments per post
# 01:17 22.50 average comments per post
# 18:22 22.50 average comments per post
# 05:13 22.00 average comments per post
# 02:05 22.00 average comments per post
# 01:51 22.00 average comments per post
# 19:32 22.00 average comments per post
# 15:46 22.00 average comments per post
# 15:20 22.00 average comments per post
# 14:47 22.00 average comments per post
# 08:37 21.50 average comments per post
# 16:05 21.50 average comments per post
# 05:15 21.33 average comments per post
# 06:44 21.00 average comments per post
# 06:05 21.00 average comments per post
# 01:40 21.00 average comments per post
# 01:11 21.00 average comments per post
# 18:02 21.00 average comments per post
# 15:16 21.00 average comments per post
# 07:57 20.00 average comments per post
# 23:18 20.00 average comments per post
# 22:24 20.00 average comments per post
# 19:39 20.00 average comments per post
# 21:53 19.50 average comments per post
# 01:47 19.50 average comments per post
# 04:07 19.00 average comments per post
# 22:31 19.00 average comments per post
# 20:00 19.00 average comments per post
# 15:22 19.00 average comments per post
# 12:58 19.00 average comments per post
# 10:57 19.00 average comments per post
# 05:33 18.00 average comments per post
# 04:55 18.00 average comments per post
# 03:09 18.00 average comments per post
# 19:04 18.00 average comments per post
# 14:55 18.00 average comments per post
# 10:16 18.00 average comments per post
# 02:58 17.50 average comments per post
# 20:04 17.50 average comments per post
# 16:37 17.50 average comments per post
# 10:50 17.50 average comments per post
# 09:42 17.00 average comments per post
# 03:21 17.00 average comments per post
# 22:39 17.00 average comments per post
# 21:58 17.00 average comments per post
# 18:42 17.00 average comments per post
# 18:34 17.00 average comments per post
# 17:27 17.00 average comments per post
# 16:44 17.00 average comments per post
# 16:01 16.75 average comments per post
# 23:57 16.67 average comments per post
# 23:00 16.67 average comments per post
# 18:00 16.50 average comments per post
# 22:57 16.33 average comments per post
# 05:34 16.00 average comments per post
# 03:01 16.00 average comments per post
# 22:07 16.00 average comments per post
# 21:44 16.00 average comments per post
# 18:19 16.00 average comments per post
# 15:29 16.00 average comments per post
# 15:19 15.33 average comments per post
# 21:09 15.00 average comments per post
# 01:05 15.00 average comments per post
# 13:22 15.00 average comments per post
# 11:54 15.00 average comments per post
# 22:06 14.50 average comments per post
# 01:45 14.50 average comments per post
# 13:09 14.50 average comments per post
# 20:59 14.33 average comments per post
# 02:36 14.25 average comments per post
# 07:23 14.00 average comments per post
# 03:52 14.00 average comments per post
# 03:20 14.00 average comments per post
# 19:23 14.00 average comments per post
# 17:25 14.00 average comments per post
# 13:25 14.00 average comments per post
# 00:59 14.00 average comments per post
# 02:34 13.50 average comments per post
# 23:43 13.50 average comments per post
# 21:18 13.50 average comments per post
# 14:33 13.33 average comments per post
# 22:54 13.00 average comments per post
# 17:13 13.00 average comments per post
# 16:28 12.67 average comments per post
# 19:43 12.50 average comments per post
# 18:55 12.50 average comments per post
# 17:48 12.50 average comments per post
# 10:42 12.50 average comments per post
# 08:39 12.33 average comments per post
# 19:49 12.25 average comments per post
# 07:25 12.00 average comments per post
# 03:53 12.00 average comments per post
# 22:17 12.00 average comments per post
# 22:14 12.00 average comments per post
# 16:10 12.00 average comments per post
# 10:48 12.00 average comments per post
# 10:22 12.00 average comments per post
# 00:42 12.00 average comments per post
# 00:38 12.00 average comments per post
# 04:41 11.67 average comments per post
# 03:46 11.67 average comments per post
# 18:32 11.67 average comments per post
# 07:55 11.50 average comments per post
# 14:48 11.50 average comments per post
# 12:30 11.50 average comments per post
# 21:15 11.33 average comments per post
# 20:54 11.33 average comments per post
# 07:10 11.00 average comments per post
# 07:05 11.00 average comments per post
# 04:24 11.00 average comments per post
# 03:26 11.00 average comments per post
# 23:21 11.00 average comments per post
# 19:20 11.00 average comments per post
# 18:52 11.00 average comments per post
# 17:40 11.00 average comments per post
# 17:21 11.00 average comments per post
# 17:07 11.00 average comments per post
# 17:06 11.00 average comments per post
# 20:48 10.75 average comments per post
# 18:06 10.75 average comments per post
# 01:44 10.50 average comments per post
# 19:18 10.50 average comments per post
# 06:26 10.00 average comments per post
# 05:46 10.00 average comments per post
# 04:01 10.00 average comments per post
# 03:39 10.00 average comments per post
# 02:23 10.00 average comments per post
# 17:37 10.00 average comments per post
# 16:53 10.00 average comments per post
# 12:22 10.00 average comments per post
# 11:08 10.00 average comments per post
# 10:17 10.00 average comments per post
# 00:58 10.00 average comments per post
# 02:17 9.50 average comments per post
# 21:57 9.50 average comments per post
# 18:41 9.50 average comments per post
# 14:54 9.50 average comments per post
# 12:31 9.50 average comments per post
# 00:50 9.50 average comments per post
# 19:08 9.33 average comments per post
# 13:17 9.33 average comments per post
# 23:37 9.25 average comments per post
# 18:13 9.25 average comments per post
# 13:34 9.20 average comments per post
# 08:41 9.00 average comments per post
# 05:16 9.00 average comments per post
# 04:40 9.00 average comments per post
# 03:28 9.00 average comments per post
# 03:17 9.00 average comments per post
# 22:01 9.00 average comments per post
# 21:59 9.00 average comments per post
# 20:46 9.00 average comments per post
# 01:03 9.00 average comments per post
# 18:36 9.00 average comments per post
# 18:04 9.00 average comments per post
# 17:24 9.00 average comments per post
# 17:10 9.00 average comments per post
# 16:36 9.00 average comments per post
# 14:42 9.00 average comments per post
# 14:29 9.00 average comments per post
# 14:08 9.00 average comments per post
# 13:14 9.00 average comments per post
# 13:00 9.00 average comments per post
# 12:09 9.00 average comments per post
# 12:07 9.00 average comments per post
# 11:50 9.00 average comments per post
# 16:51 8.67 average comments per post
# 03:19 8.50 average comments per post
# 18:12 8.50 average comments per post
# 13:53 8.50 average comments per post
# 12:14 8.50 average comments per post
# 06:33 8.33 average comments per post
# 21:34 8.33 average comments per post
# 01:52 8.33 average comments per post
# 19:38 8.33 average comments per post
# 16:52 8.25 average comments per post
# 16:38 8.25 average comments per post
# 14:59 8.25 average comments per post
# 09:31 8.00 average comments per post
# 07:52 8.00 average comments per post
# 07:06 8.00 average comments per post
# 06:03 8.00 average comments per post
# 04:26 8.00 average comments per post
# 03:37 8.00 average comments per post
# 02:30 8.00 average comments per post
# 02:08 8.00 average comments per post
# 02:02 8.00 average comments per post
# 23:38 8.00 average comments per post
# 23:25 8.00 average comments per post
# 21:48 8.00 average comments per post
# 20:26 8.00 average comments per post
# 20:02 8.00 average comments per post
# 01:27 8.00 average comments per post
# 17:11 8.00 average comments per post
# 16:59 8.00 average comments per post
# 16:48 8.00 average comments per post
# 16:45 8.00 average comments per post
# 16:26 8.00 average comments per post
# 16:15 8.00 average comments per post
# 16:00 8.00 average comments per post
# 15:59 8.00 average comments per post
# 14:28 8.00 average comments per post
# 13:18 8.00 average comments per post
# 13:13 8.00 average comments per post
# 00:35 8.00 average comments per post
# 00:09 8.00 average comments per post
# 22:09 7.80 average comments per post
# 05:09 7.67 average comments per post
# 22:41 7.67 average comments per post
# 19:27 7.67 average comments per post
# 14:27 7.67 average comments per post
# 06:29 7.50 average comments per post
# 04:53 7.50 average comments per post
# 22:05 7.50 average comments per post
# 20:28 7.50 average comments per post
# 18:58 7.50 average comments per post
# 16:30 7.50 average comments per post
# 15:38 7.50 average comments per post
# 14:52 7.50 average comments per post
# 13:36 7.50 average comments per post
# 12:43 7.50 average comments per post
# 11:14 7.50 average comments per post
# 09:56 7.00 average comments per post
# 07:26 7.00 average comments per post
# 06:37 7.00 average comments per post
# 04:05 7.00 average comments per post
# 04:03 7.00 average comments per post
# 03:12 7.00 average comments per post
# 02:50 7.00 average comments per post
# 23:32 7.00 average comments per post
# 22:27 7.00 average comments per post
# 22:26 7.00 average comments per post
# 20:29 7.00 average comments per post
# 20:25 7.00 average comments per post
# 20:19 7.00 average comments per post
# 01:34 7.00 average comments per post
# 19:58 7.00 average comments per post
# 18:57 7.00 average comments per post
# 18:10 7.00 average comments per post
# 17:35 7.00 average comments per post
# 17:26 7.00 average comments per post
# 17:22 7.00 average comments per post
# 17:04 7.00 average comments per post
# 16:25 7.00 average comments per post
# 16:22 7.00 average comments per post
# 14:31 7.00 average comments per post
# 14:06 7.00 average comments per post
# 13:59 7.00 average comments per post
# 13:03 7.00 average comments per post
# 12:52 7.00 average comments per post
# 12:42 7.00 average comments per post
# 12:23 7.00 average comments per post
# 12:00 7.00 average comments per post
# 11:26 7.00 average comments per post
# 10:51 7.00 average comments per post
# 10:28 7.00 average comments per post
# 10:05 7.00 average comments per post
# 19:16 6.67 average comments per post
# 18:05 6.67 average comments per post
# 07:28 6.50 average comments per post
# 05:36 6.50 average comments per post
# 04:59 6.50 average comments per post
# 02:21 6.50 average comments per post
# 19:52 6.50 average comments per post
# 18:25 6.50 average comments per post
# 14:57 6.50 average comments per post
# 00:31 6.50 average comments per post
# 00:25 6.50 average comments per post
# 16:49 6.40 average comments per post
# 21:45 6.33 average comments per post
# 21:06 6.33 average comments per post
# 19:24 6.33 average comments per post
# 15:08 6.33 average comments per post
# 14:07 6.33 average comments per post
# 00:20 6.33 average comments per post
# 08:43 6.00 average comments per post
# 07:46 6.00 average comments per post
# 07:13 6.00 average comments per post
# 07:09 6.00 average comments per post
# 05:08 6.00 average comments per post
# 04:58 6.00 average comments per post
# 02:13 6.00 average comments per post
# 23:30 6.00 average comments per post
# 23:22 6.00 average comments per post
# 22:35 6.00 average comments per post
# 22:16 6.00 average comments per post
# 21:50 6.00 average comments per post
# 21:12 6.00 average comments per post
# 21:01 6.00 average comments per post
# 20:33 6.00 average comments per post
# 20:03 6.00 average comments per post
# 01:13 6.00 average comments per post
# 18:47 6.00 average comments per post
# 16:03 6.00 average comments per post
# 15:33 6.00 average comments per post
# 15:28 6.00 average comments per post
# 15:18 6.00 average comments per post
# 15:09 6.00 average comments per post
# 14:37 6.00 average comments per post
# 13:05 6.00 average comments per post
# 12:56 6.00 average comments per post
# 12:32 6.00 average comments per post
# 11:57 6.00 average comments per post
# 11:35 6.00 average comments per post
# 10:55 6.00 average comments per post
# 00:18 5.75 average comments per post
# 22:34 5.67 average comments per post
# 17:38 5.67 average comments per post
# 15:31 5.67 average comments per post
# 15:11 5.67 average comments per post
# 11:09 5.67 average comments per post
# 22:51 5.57 average comments per post
# 08:01 5.50 average comments per post
# 07:17 5.50 average comments per post
# 06:20 5.50 average comments per post
# 21:17 5.50 average comments per post
# 20:49 5.50 average comments per post
# 19:36 5.50 average comments per post
# 18:51 5.50 average comments per post
# 18:40 5.50 average comments per post
# 18:24 5.50 average comments per post
# 17:56 5.50 average comments per post
# 17:36 5.50 average comments per post
# 17:33 5.50 average comments per post
# 16:06 5.50 average comments per post
# 13:28 5.50 average comments per post
# 12:45 5.50 average comments per post
# 12:25 5.50 average comments per post
# 10:31 5.50 average comments per post
# 18:49 5.33 average comments per post
# 17:23 5.33 average comments per post
# 16:56 5.33 average comments per post
# 13:24 5.33 average comments per post
# 09:12 5.00 average comments per post
# 08:27 5.00 average comments per post
# 08:19 5.00 average comments per post
# 07:47 5.00 average comments per post
# 07:15 5.00 average comments per post
# 06:50 5.00 average comments per post
# 05:57 5.00 average comments per post
# 05:21 5.00 average comments per post
# 05:19 5.00 average comments per post
# 05:02 5.00 average comments per post
# 04:37 5.00 average comments per post
# 04:20 5.00 average comments per post
# 03:38 5.00 average comments per post
# 03:33 5.00 average comments per post
# 03:03 5.00 average comments per post
# 02:49 5.00 average comments per post
# 02:37 5.00 average comments per post
# 23:36 5.00 average comments per post
# 23:33 5.00 average comments per post
# 23:29 5.00 average comments per post
# 21:52 5.00 average comments per post
# 21:43 5.00 average comments per post
# 21:38 5.00 average comments per post
# 21:10 5.00 average comments per post
# 20:56 5.00 average comments per post
# 20:53 5.00 average comments per post
# 20:31 5.00 average comments per post
# 01:26 5.00 average comments per post
# 19:34 5.00 average comments per post
# 19:26 5.00 average comments per post
# 19:14 5.00 average comments per post
# 19:03 5.00 average comments per post
# 18:28 5.00 average comments per post
# 17:30 5.00 average comments per post
# 17:08 5.00 average comments per post
# 14:40 5.00 average comments per post
# 13:54 5.00 average comments per post
# 13:42 5.00 average comments per post
# 12:21 5.00 average comments per post
# 12:16 5.00 average comments per post
# 11:46 5.00 average comments per post
# 11:04 5.00 average comments per post
# 10:26 5.00 average comments per post
# 00:15 5.00 average comments per post
# 21:27 4.80 average comments per post
# 21:35 4.75 average comments per post
# 23:35 4.67 average comments per post
# 23:23 4.67 average comments per post
# 01:02 4.67 average comments per post
# 14:20 4.67 average comments per post
# 07:54 4.50 average comments per post
# 02:42 4.50 average comments per post
# 23:19 4.50 average comments per post
# 22:13 4.50 average comments per post
# 21:46 4.50 average comments per post
# 19:53 4.50 average comments per post
# 12:01 4.50 average comments per post
# 11:47 4.50 average comments per post
# 11:18 4.50 average comments per post
# 09:04 4.33 average comments per post
# 08:30 4.33 average comments per post
# 22:15 4.33 average comments per post
# 16:50 4.33 average comments per post
# 14:13 4.33 average comments per post
# 13:44 4.33 average comments per post
# 12:57 4.25 average comments per post
# 12:47 4.25 average comments per post
# 21:13 4.17 average comments per post
# 09:47 4.00 average comments per post
# 09:45 4.00 average comments per post
# 09:43 4.00 average comments per post
# 09:35 4.00 average comments per post
# 09:21 4.00 average comments per post
# 08:53 4.00 average comments per post
# 08:48 4.00 average comments per post
# 08:14 4.00 average comments per post
# 08:13 4.00 average comments per post
# 06:42 4.00 average comments per post
# 06:39 4.00 average comments per post
# 06:25 4.00 average comments per post
# 06:19 4.00 average comments per post
# 05:59 4.00 average comments per post
# 05:29 4.00 average comments per post
# 04:56 4.00 average comments per post
# 03:54 4.00 average comments per post
# 03:31 4.00 average comments per post
# 03:06 4.00 average comments per post
# 03:04 4.00 average comments per post
# 02:53 4.00 average comments per post
# 02:33 4.00 average comments per post
# 02:15 4.00 average comments per post
# 22:18 4.00 average comments per post
# 21:28 4.00 average comments per post
# 21:26 4.00 average comments per post
# 21:16 4.00 average comments per post
# 20:38 4.00 average comments per post
# 20:35 4.00 average comments per post
# 01:59 4.00 average comments per post
# 01:50 4.00 average comments per post
# 01:25 4.00 average comments per post
# 19:35 4.00 average comments per post
# 19:29 4.00 average comments per post
# 19:17 4.00 average comments per post
# 19:12 4.00 average comments per post
# 19:07 4.00 average comments per post
# 19:06 4.00 average comments per post
# 18:30 4.00 average comments per post
# 17:01 4.00 average comments per post
# 16:20 4.00 average comments per post
# 15:58 4.00 average comments per post
# 15:55 4.00 average comments per post
# 15:37 4.00 average comments per post
# 15:14 4.00 average comments per post
# 13:51 4.00 average comments per post
# 13:38 4.00 average comments per post
# 13:30 4.00 average comments per post
# 12:24 4.00 average comments per post
# 12:03 4.00 average comments per post
# 12:02 4.00 average comments per post
# 11:44 4.00 average comments per post
# 11:41 4.00 average comments per post
# 11:40 4.00 average comments per post
# 11:03 4.00 average comments per post
# 10:52 4.00 average comments per post
# 10:47 4.00 average comments per post
# 10:44 4.00 average comments per post
# 10:39 4.00 average comments per post
# 10:20 4.00 average comments per post
# 10:07 4.00 average comments per post
# 00:56 4.00 average comments per post
# 00:01 4.00 average comments per post
# 20:27 3.83 average comments per post
# 18:23 3.80 average comments per post
# 18:33 3.75 average comments per post
# 02:19 3.67 average comments per post
# 23:49 3.67 average comments per post
# 20:12 3.67 average comments per post
# 18:54 3.67 average comments per post
# 16:41 3.67 average comments per post
# 15:50 3.67 average comments per post
# 15:45 3.67 average comments per post
# 12:54 3.67 average comments per post
# 11:51 3.67 average comments per post
# 15:03 3.60 average comments per post
# 09:28 3.50 average comments per post
# 09:24 3.50 average comments per post
# 08:03 3.50 average comments per post
# 04:25 3.50 average comments per post
# 23:48 3.50 average comments per post
# 21:37 3.50 average comments per post
# 21:19 3.50 average comments per post
# 01:58 3.50 average comments per post
# 19:41 3.50 average comments per post
# 19:22 3.50 average comments per post
# 18:21 3.50 average comments per post
# 17:46 3.50 average comments per post
# 16:42 3.50 average comments per post
# 16:27 3.50 average comments per post
# 15:57 3.50 average comments per post
# 15:34 3.50 average comments per post
# 15:15 3.50 average comments per post
# 13:26 3.50 average comments per post
# 11:43 3.50 average comments per post
# 11:37 3.50 average comments per post
# 00:22 3.50 average comments per post
# 18:20 3.43 average comments per post
# 02:57 3.33 average comments per post
# 20:07 3.33 average comments per post
# 19:33 3.33 average comments per post
# 19:09 3.33 average comments per post
# 14:36 3.33 average comments per post
# 13:45 3.33 average comments per post
# 09:55 3.25 average comments per post
# 23:24 3.25 average comments per post
# 22:38 3.25 average comments per post
# 13:12 3.25 average comments per post
# 09:44 3.00 average comments per post
# 09:06 3.00 average comments per post
# 08:46 3.00 average comments per post
# 08:26 3.00 average comments per post
# 07:11 3.00 average comments per post
# 07:03 3.00 average comments per post
# 06:21 3.00 average comments per post
# 06:01 3.00 average comments per post
# 05:53 3.00 average comments per post
# 05:28 3.00 average comments per post
# 05:25 3.00 average comments per post
# 04:51 3.00 average comments per post
# 04:47 3.00 average comments per post
# 04:43 3.00 average comments per post
# 03:30 3.00 average comments per post
# 03:27 3.00 average comments per post
# 02:47 3.00 average comments per post
# 23:53 3.00 average comments per post
# 23:40 3.00 average comments per post
# 22:59 3.00 average comments per post
# 22:55 3.00 average comments per post
# 22:43 3.00 average comments per post
# 22:40 3.00 average comments per post
# 22:02 3.00 average comments per post
# 21:47 3.00 average comments per post
# 21:42 3.00 average comments per post
# 21:40 3.00 average comments per post
# 21:39 3.00 average comments per post
# 21:14 3.00 average comments per post
# 21:11 3.00 average comments per post
# 20:55 3.00 average comments per post
# 20:21 3.00 average comments per post
# 20:15 3.00 average comments per post
# 20:10 3.00 average comments per post
# 01:56 3.00 average comments per post
# 01:54 3.00 average comments per post
# 01:15 3.00 average comments per post
# 01:01 3.00 average comments per post
# 19:56 3.00 average comments per post
# 19:47 3.00 average comments per post
# 19:15 3.00 average comments per post
# 18:48 3.00 average comments per post
# 18:16 3.00 average comments per post
# 17:54 3.00 average comments per post
# 17:52 3.00 average comments per post
# 17:49 3.00 average comments per post
# 17:41 3.00 average comments per post
# 17:39 3.00 average comments per post
# 17:12 3.00 average comments per post
# 16:55 3.00 average comments per post
# 16:32 3.00 average comments per post
# 15:48 3.00 average comments per post
# 15:39 3.00 average comments per post
# 15:36 3.00 average comments per post
# 15:17 3.00 average comments per post
# 14:49 3.00 average comments per post
# 14:18 3.00 average comments per post
# 13:56 3.00 average comments per post
# 12:59 3.00 average comments per post
# 12:50 3.00 average comments per post
# 12:37 3.00 average comments per post
# 12:05 3.00 average comments per post
# 11:25 3.00 average comments per post
# 11:19 3.00 average comments per post
# 11:07 3.00 average comments per post
# 11:02 3.00 average comments per post
# 10:45 3.00 average comments per post
# 10:43 3.00 average comments per post
# 10:23 3.00 average comments per post
# 00:48 3.00 average comments per post
# 00:29 3.00 average comments per post
# 00:23 3.00 average comments per post
# 00:21 3.00 average comments per post
# 19:40 2.75 average comments per post
# 17:58 2.75 average comments per post
# 19:21 2.67 average comments per post
# 17:44 2.67 average comments per post
# 14:38 2.67 average comments per post
# 08:50 2.50 average comments per post
# 08:47 2.50 average comments per post
# 06:24 2.50 average comments per post
# 04:44 2.50 average comments per post
# 03:23 2.50 average comments per post
# 02:43 2.50 average comments per post
# 23:56 2.50 average comments per post
# 23:10 2.50 average comments per post
# 22:32 2.50 average comments per post
# 20:13 2.50 average comments per post
# 01:14 2.50 average comments per post
# 01:07 2.50 average comments per post
# 18:53 2.50 average comments per post
# 18:50 2.50 average comments per post
# 15:04 2.50 average comments per post
# 14:41 2.50 average comments per post
# 14:14 2.50 average comments per post
# 12:46 2.50 average comments per post
# 12:26 2.50 average comments per post
# 12:06 2.50 average comments per post
# 04:42 2.33 average comments per post
# 19:59 2.33 average comments per post
# 16:24 2.33 average comments per post
# 16:04 2.33 average comments per post
# 19:54 2.25 average comments per post
# 17:53 2.25 average comments per post
# 14:17 2.25 average comments per post
# 09:53 2.00 average comments per post
# 09:50 2.00 average comments per post
# 09:39 2.00 average comments per post
# 09:36 2.00 average comments per post
# 09:32 2.00 average comments per post
# 09:18 2.00 average comments per post
# 09:17 2.00 average comments per post
# 08:58 2.00 average comments per post
# 08:21 2.00 average comments per post
# 08:16 2.00 average comments per post
# 07:36 2.00 average comments per post
# 07:27 2.00 average comments per post
# 07:16 2.00 average comments per post
# 07:12 2.00 average comments per post
# 06:57 2.00 average comments per post
# 06:51 2.00 average comments per post
# 06:49 2.00 average comments per post
# 06:34 2.00 average comments per post
# 06:32 2.00 average comments per post
# 06:31 2.00 average comments per post
# 05:56 2.00 average comments per post
# 05:50 2.00 average comments per post
# 05:47 2.00 average comments per post
# 05:43 2.00 average comments per post
# 05:41 2.00 average comments per post
# 05:27 2.00 average comments per post
# 05:11 2.00 average comments per post
# 05:10 2.00 average comments per post
# 04:38 2.00 average comments per post
# 04:33 2.00 average comments per post
# 04:31 2.00 average comments per post
# 04:23 2.00 average comments per post
# 04:22 2.00 average comments per post
# 04:13 2.00 average comments per post
# 04:09 2.00 average comments per post
# 04:00 2.00 average comments per post
# 03:59 2.00 average comments per post
# 03:55 2.00 average comments per post
# 03:16 2.00 average comments per post
# 03:10 2.00 average comments per post
# 02:52 2.00 average comments per post
# 02:35 2.00 average comments per post
# 02:25 2.00 average comments per post
# 02:03 2.00 average comments per post
# 23:52 2.00 average comments per post
# 23:34 2.00 average comments per post
# 23:28 2.00 average comments per post
# 23:26 2.00 average comments per post
# 23:06 2.00 average comments per post
# 23:02 2.00 average comments per post
# 22:47 2.00 average comments per post
# 22:42 2.00 average comments per post
# 22:20 2.00 average comments per post
# 22:19 2.00 average comments per post
# 22:04 2.00 average comments per post
# 21:36 2.00 average comments per post
# 21:24 2.00 average comments per post
# 21:08 2.00 average comments per post
# 20:51 2.00 average comments per post
# 20:50 2.00 average comments per post
# 20:41 2.00 average comments per post
# 20:36 2.00 average comments per post
# 20:34 2.00 average comments per post
# 01:46 2.00 average comments per post
# 01:28 2.00 average comments per post
# 01:16 2.00 average comments per post
# 01:06 2.00 average comments per post
# 19:57 2.00 average comments per post
# 19:46 2.00 average comments per post
# 19:01 2.00 average comments per post
# 19:00 2.00 average comments per post
# 18:45 2.00 average comments per post
# 18:43 2.00 average comments per post
# 18:39 2.00 average comments per post
# 18:01 2.00 average comments per post
# 17:57 2.00 average comments per post
# 17:45 2.00 average comments per post
# 17:28 2.00 average comments per post
# 17:17 2.00 average comments per post
# 17:14 2.00 average comments per post
# 16:58 2.00 average comments per post
# 16:46 2.00 average comments per post
# 16:40 2.00 average comments per post
# 16:39 2.00 average comments per post
# 16:35 2.00 average comments per post
# 16:16 2.00 average comments per post
# 15:25 2.00 average comments per post
# 15:13 2.00 average comments per post
# 14:56 2.00 average comments per post
# 14:39 2.00 average comments per post
# 14:32 2.00 average comments per post
# 14:24 2.00 average comments per post
# 14:05 2.00 average comments per post
# 14:04 2.00 average comments per post
# 14:00 2.00 average comments per post
# 13:58 2.00 average comments per post
# 13:48 2.00 average comments per post
# 13:41 2.00 average comments per post
# 13:08 2.00 average comments per post
# 12:48 2.00 average comments per post
# 12:41 2.00 average comments per post
# 12:15 2.00 average comments per post
# 11:55 2.00 average comments per post
# 11:42 2.00 average comments per post
# 11:28 2.00 average comments per post
# 11:16 2.00 average comments per post
# 11:11 2.00 average comments per post
# 10:49 2.00 average comments per post
# 10:34 2.00 average comments per post
# 10:30 2.00 average comments per post
# 10:14 2.00 average comments per post
# 10:00 2.00 average comments per post
# 00:55 2.00 average comments per post
# 00:49 2.00 average comments per post
# 00:43 2.00 average comments per post
# 00:36 2.00 average comments per post
# 00:24 2.00 average comments per post
# 00:07 2.00 average comments per post
# 00:06 2.00 average comments per post
# 00:03 2.00 average comments per post
# 03:25 1.75 average comments per post
# 15:44 1.75 average comments per post
# 03:51 1.67 average comments per post
# 10:40 1.67 average comments per post
# 08:40 1.50 average comments per post
# 08:28 1.50 average comments per post
# 06:14 1.50 average comments per post
# 23:45 1.50 average comments per post
# 21:56 1.50 average comments per post
# 21:55 1.50 average comments per post
# 20:44 1.50 average comments per post
# 20:20 1.50 average comments per post
# 19:42 1.50 average comments per post
# 17:16 1.50 average comments per post
# 15:06 1.50 average comments per post
# 14:44 1.50 average comments per post
# 14:21 1.50 average comments per post
# 13:49 1.50 average comments per post
# 13:16 1.50 average comments per post
# 12:04 1.50 average comments per post
# 09:22 1.33 average comments per post
# 21:32 1.33 average comments per post
# 09:58 1.00 average comments per post
# 09:29 1.00 average comments per post
# 09:25 1.00 average comments per post
# 09:20 1.00 average comments per post
# 08:59 1.00 average comments per post
# 08:36 1.00 average comments per post
# 08:32 1.00 average comments per post
# 08:10 1.00 average comments per post
# 07:38 1.00 average comments per post
# 07:31 1.00 average comments per post
# 06:27 1.00 average comments per post
# 06:17 1.00 average comments per post
# 05:37 1.00 average comments per post
# 05:31 1.00 average comments per post
# 05:12 1.00 average comments per post
# 05:00 1.00 average comments per post
# 04:57 1.00 average comments per post
# 04:52 1.00 average comments per post
# 04:18 1.00 average comments per post
# 04:02 1.00 average comments per post
# 03:35 1.00 average comments per post
# 03:34 1.00 average comments per post
# 03:29 1.00 average comments per post
# 03:14 1.00 average comments per post
# 02:51 1.00 average comments per post
# 02:44 1.00 average comments per post
# 02:41 1.00 average comments per post
# 02:40 1.00 average comments per post
# 02:39 1.00 average comments per post
# 02:31 1.00 average comments per post
# 02:16 1.00 average comments per post
# 23:44 1.00 average comments per post
# 23:31 1.00 average comments per post
# 23:14 1.00 average comments per post
# 23:09 1.00 average comments per post
# 23:08 1.00 average comments per post
# 22:50 1.00 average comments per post
# 22:49 1.00 average comments per post
# 22:44 1.00 average comments per post
# 22:36 1.00 average comments per post
# 21:49 1.00 average comments per post
# 21:30 1.00 average comments per post
# 21:29 1.00 average comments per post
# 21:25 1.00 average comments per post
# 21:22 1.00 average comments per post
# 20:37 1.00 average comments per post
# 20:23 1.00 average comments per post
# 20:14 1.00 average comments per post
# 20:08 1.00 average comments per post
# 01:53 1.00 average comments per post
# 01:43 1.00 average comments per post
# 19:51 1.00 average comments per post
# 19:31 1.00 average comments per post
# 19:25 1.00 average comments per post
# 19:05 1.00 average comments per post
# 19:02 1.00 average comments per post
# 18:37 1.00 average comments per post
# 18:27 1.00 average comments per post
# 18:11 1.00 average comments per post
# 17:59 1.00 average comments per post
# 17:51 1.00 average comments per post
# 17:19 1.00 average comments per post
# 16:54 1.00 average comments per post
# 16:34 1.00 average comments per post
# 16:33 1.00 average comments per post
# 16:19 1.00 average comments per post
# 16:18 1.00 average comments per post
# 16:12 1.00 average comments per post
# 16:08 1.00 average comments per post
# 15:54 1.00 average comments per post
# 15:53 1.00 average comments per post
# 15:51 1.00 average comments per post
# 15:30 1.00 average comments per post
# 15:26 1.00 average comments per post
# 15:21 1.00 average comments per post
# 15:12 1.00 average comments per post
# 15:02 1.00 average comments per post
# 14:51 1.00 average comments per post
# 14:22 1.00 average comments per post
# 14:19 1.00 average comments per post
# 14:10 1.00 average comments per post
# 14:09 1.00 average comments per post
# 14:03 1.00 average comments per post
# 13:50 1.00 average comments per post
# 13:46 1.00 average comments per post
# 13:29 1.00 average comments per post
# 12:34 1.00 average comments per post
# 12:20 1.00 average comments per post
# 12:11 1.00 average comments per post
# 11:49 1.00 average comments per post
# 11:38 1.00 average comments per post
# 11:31 1.00 average comments per post
# 11:13 1.00 average comments per post
# 11:10 1.00 average comments per post
# 11:06 1.00 average comments per post
# 10:58 1.00 average comments per post
# 10:56 1.00 average comments per post
# 10:53 1.00 average comments per post
# 10:41 1.00 average comments per post
# 10:21 1.00 average comments per post
# 10:15 1.00 average comments per post
# 10:13 1.00 average comments per post
# 00:51 1.00 average comments per post
# 00:47 1.00 average comments per post
# 00:41 1.00 average comments per post
# 00:27 1.00 average comments per post
# 00:19 1.00 average comments per post
# 00:14 1.00 average comments per post
# 00:08 1.00 average comments per post
